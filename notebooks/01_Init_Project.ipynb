# %%
# Import libraries
# Selenium: Automate web browser interactions.
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import requests

# Polars: A high-performance DataFrame library.
import polars as pl
import pandas as pd

# Time: For adding delays during browser interactions.
import time

# Import custom functions
import os  # Provides functions for interacting with the operating system.
import sys  # Allows interaction with the Python runtime environment.

# Import scrape_mercadona function from src.main module
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.main import *

# %%
# Llamar a la función para scrapeo de las páginas 0 a 1000

df = scrape_mercadona(0, 1000)

# %%
# Create ID's
df = df.with_columns(
    pl.arange(1, df.height + 1).alias("id")
)


# Reorganizar las columnas para que 'id' sea la primera
df = df.select(["id", "Category", "name", "subtitle", "price", "discount_price", "main_image_url", "secondary_image_url"])
df

# %%
# Create Category folders.
create_category_folders(df, base_path="./categories")

# Descargar las imágenes
for i, row in df.iterrows():
    category = row["Category"]
    img_url = row["main_image_url"]
    img_path = f"../img/{category}/{row['id']}.jpg"
    download_image(img_url, img_path)

    # Descargar la imagen secundaria
    img_url = row["secondary_image_url"]
    img_path = f"../img/{category}/{row['id']}_secondary.jpg"
    download_image(img_url, img_path)

print("Descarga completada.")

# %%
# Save the DataFrame to a CSV file.
df.to_csv("../data/processed/mercadona.csv", index=False)
